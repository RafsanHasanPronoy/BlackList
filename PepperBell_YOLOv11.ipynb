# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanHasanPronoy/BlackList/blob/main/PepperBell_YOLOv11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.8/978.8 kB 42.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 93.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 63.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 97.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !unzip /content/PepperBell.zip
# Out:
# Archive:  /content/PepperBell.zip
#    creating: PepperBell/
#    creating: PepperBell/train/
#    creating: PepperBell/train/Pepper__bell___Bacterial_spot/
#   inflating: PepperBell/train/Pepper__bell___Bacterial_spot/0022d6b7-d47c-4ee2-ae9a-392a53f48647___JR_B-Spot-8964_JPG.rf.03ab3c9ddf2ed0f373cef58377c96e39.jpg
#   inflating: PepperBell/train/Pepper__bell___Bacterial_spot/006adb74-934f-448f-a14f-62181742127b___JR_B-Spot-3395_JPG.rf.7bb0f6ca93b655a267ef36001276aeee.jpg
#   inflating: PepperBell/train/Pepper__bell___Bacterial_spot/00f2e69a-1e56-412d-8a79-fdce794a17e4___JR_B-Spot-3132_JPG.rf.cb5f88252baa07e17870729bd8b108a6.jpg
#   inflating: PepperBell/train/Pepper__bell___Bacterial_spot/01613cd0-d3cd-4e96-945c-a312002037bf___JR_B-Spot-3262_JPG.rf.a2e41a9ef1f7cb0738ffd9ef31615f31.jpg
#   inflating: PepperBell/train/Pepper__bell___Bacterial_spot/0169b9ac-07b9-4be1-8b85-da94481f05a4___NREC_B-Spot-9169_JPG.rf.440fba8948213ba170ac9d1bbae44b5e.jpg
# ...

# %%
from ultralytics import YOLO

#loading classification model
model = YOLO('yolo11n-cls.pt')

#train the model
results = model.train(data='/content/PepperBell', epochs=10, imgsz=640)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 5.52M/5.52M [00:00<00:00, 175MB/s]
# Ultralytics 8.3.111 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from IPython.display import Image

# %%
Image("/content/runs/classify/train/results.png", width=600)

# %%
Image("/content/runs/classify/train/confusion_matrix.png", width=600)

# %%
model = YOLO('/content/runs/classify/train/weights/best.pt')

results = model("/content/fed15b37-0129-4436-a832-d98d9f446f9a___JR_HL-8437_JPG.rf.87acf041236c11c5c1aee18e2166fbb3.jpg") #, save=True, conf=0.5)
results[0].show()
# Out:
# image 1/1 /content/fed15b37-0129-4436-a832-d98d9f446f9a___JR_HL-8437_JPG.rf.87acf041236c11c5c1aee18e2166fbb3.jpg: 640x640 Pepper__bell___healthy 1.00, Pepper__bell___Bacterial_spot 0.00, 9.5ms
# Speed: 25.1ms preprocess, 9.5ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
results = model("/content/ff42d153-cf08-4582-93b7-c97ac740331a___JR_HL-8531_JPG.rf.7ac5ededef5c85b3b94973316a751c17.jpg") #, save=True, conf=0.5)
results[0].show()
# Out:
# image 1/1 /content/ff42d153-cf08-4582-93b7-c97ac740331a___JR_HL-8531_JPG.rf.7ac5ededef5c85b3b94973316a751c17.jpg: 640x640 Pepper__bell___healthy 1.00, Pepper__bell___Bacterial_spot 0.00, 6.2ms
# Speed: 12.4ms preprocess, 6.2ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
results = model("/content/a30b2b1d-6dd4-4322-8950-f85c5b946c5a___NREC_B-Spot-9152_JPG.rf.6677e3b811e0a5db8fb4933ad643c5da.jpg") #, save=True, conf=0.5)
results[0].show()
# Out:
# image 1/1 /content/a30b2b1d-6dd4-4322-8950-f85c5b946c5a___NREC_B-Spot-9152_JPG.rf.6677e3b811e0a5db8fb4933ad643c5da.jpg: 640x640 Pepper__bell___Bacterial_spot 1.00, Pepper__bell___healthy 0.00, 31.1ms
# Speed: 38.0ms preprocess, 31.1ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
results = model("/content/8695a15f-cdb4-444f-817b-7f4fc22a7a7a___NREC_B-Spot-9230_JPG.rf.12bbdac092c9054faa36ce531e68c8f9.jpg") #, save=True, conf=0.5)
results[0].show()
# Out:
# image 1/1 /content/8695a15f-cdb4-444f-817b-7f4fc22a7a7a___NREC_B-Spot-9230_JPG.rf.12bbdac092c9054faa36ce531e68c8f9.jpg: 640x640 Pepper__bell___Bacterial_spot 1.00, Pepper__bell___healthy 0.00, 8.9ms
# Speed: 16.2ms preprocess, 8.9ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=640x640>
